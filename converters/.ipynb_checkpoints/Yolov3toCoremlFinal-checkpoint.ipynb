# %% [markdown]
# # imports

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model, Model
import numpy as np

print("TensorFlow version is: {}".format(tf.__version__))
print("Eager execution is: {}".format(tf.executing_eagerly()))
print("Keras version is: {}".format(tf.keras.__version__))
# Out:
# TensorFlow version is: 2.2.0
# Eager execution is: True
# Keras version is: 2.3.0-tf

# %% [markdown]
# # labels and draw rect

# %%
def read_labels(labels_path):
    with open(labels_path) as f:
        labels = f.readlines()
    labels = [c.strip() for c in labels]
    return labels

# %%
labels = read_labels('coco.txt')
labels[:5]
# Out:
# ['person', 'bicycle', 'car', 'motorbike', 'aeroplane']

# %%
import colorsys
import random

def generate_colors(class_names):
    hsv_tuples = [(x / len(class_names), 1., 1.) for x in range(len(class_names))]
    colors = list(map(lambda x: colorsys.hsv_to_rgb(*x), hsv_tuples))
    colors = list(map(lambda x: (int(x[0] ), int(x[1] ), int(x[2] )), colors))
    random.seed(10101)  # Fixed seed for consistent colors across runs.
    random.shuffle(colors)  # Shuffle colors to decorrelate adjacent classes.
    random.seed(None)  # Reset seed to default.
    return colors

# %%
from matplotlib import pyplot
from matplotlib.patches import Rectangle

def draw_bbs(filename, yhat):
    boxes = yhat[..., :4]
    pred_conf = yhat[..., 4:]
    boxes, scores, classes, valid_detections =  tf.image.combined_non_max_suppression(
        boxes=tf.reshape(boxes, (tf.shape(boxes)[0], -1, 1, 4)),
        scores=tf.reshape(
                pred_conf, (tf.shape(pred_conf)[0], -1, tf.shape(pred_conf)[-1])),
        max_output_size_per_class=50,
        max_total_size=50,
        iou_threshold=.45,
        score_threshold=.5
    )
    pred_bbox = [boxes.numpy(), scores.numpy(), classes.numpy(), valid_detections.numpy()]
    out_boxes, out_scores, out_classes, num_boxes = pred_bbox
    print(f'num_boxes[0].shape = {num_boxes[0]} out_boxes.shape = {out_boxes.shape}')
    print('------iteration started------')
    for i in range(num_boxes[0]):
        if int(out_classes[0][i]) < 0 or int(out_classes[0][i]) > len(labels): continue
        class_ind = int(out_classes[0][i])
        coor = out_boxes[0][i]
        class_name = labels[class_ind]
        print(f'coor_{i} - {class_name} === {coor}')
        coor[0] = int(coor[0] * image_h)
        coor[2] = int(coor[2] * image_h)
        coor[1] = int(coor[1] * image_w)
        coor[3] = int(coor[3] * image_w)
        fontScale = 0.5
        score = out_scores[0][i]
        
#         print(out_boxes.shape)  
    print('------iteration completed------')
    print(out_boxes.shape)  
    print('start drawing boxes')
    data = pyplot.imread(filename)
    # plot the image
    pyplot.imshow(data)
    # get the context for drawing boxes
    ax = pyplot.gca()
    # plot each box
    
    colors = generate_colors(labels)
    out_classes = out_classes[0]
    out_scores = out_scores[0]
    out_boxes = out_boxes[0]
    print(f'out boxes shape is  {out_boxes.shape}')
    
    for i in range(num_boxes[0]):
        box = out_boxes[i]
        # get coordinates
#         print(f'box shape is {box}')
        y1, x1, y2, x2 = box[0], box[1], box[2], box[3]
        print(f'++++++++ object = {labels[int(out_classes[i])]} -   y1, x1, y2, x2 = {box[0]}, {box[1]}, {box[2]}, {box[3]}')
        # calculate width and height of the box
        width, height = x2 - x1, y2 - y1
        print(f'object = {labels[int(out_classes[i])]}({out_scores[i]*100})  w= {width}  h= {height}')
        # create the shape
        rect = Rectangle((x1, y1), width, height, fill=False, color=colors[i])
        # draw the box
        ax.add_patch(rect)
        # draw text and score in top left corner
        label = "%s (%.3f)" % (labels[int(out_classes[i])], out_scores[i]*100)
        pyplot.text(x1, y1, label, color='yellow')
#     # show the plot
    pyplot.show()

# %%
import copy
from PIL import ImageDraw, ImageColor

def draw_bbs_coreml(filename, yhat):
    boxes = yhat[..., :4]
    pred_conf = yhat[..., 4:]
    boxes, scores, classes, valid_detections =  tf.image.combined_non_max_suppression(
        boxes= tf.reshape(boxes, (tf.shape(boxes)[0], -1, 1, 4)),
        scores=tf.reshape(
                pred_conf, (tf.shape(pred_conf)[0], -1, tf.shape(pred_conf)[-1])),
        max_output_size_per_class=50,
        max_total_size=50,
        iou_threshold=.45,
        score_threshold=.5
    )
    pred_bbox = [boxes.numpy(), scores.numpy(), classes.numpy(), valid_detections.numpy()]
    out_boxes, out_scores, out_classes, num_boxes = pred_bbox
    print(f'num_boxes[0].shape = {num_boxes[0]} out_boxes.shape = {out_boxes.shape}')
    print('------iteration staretd------')
    for i in range(num_boxes[0]):
        if int(out_classes[0][i]) < 0 or int(out_classes[0][i]) > len(labels): continue
        class_ind = int(out_classes[0][i])
        coor = out_boxes[0][i]
        class_name = labels[class_ind]
        new_coor = np.copy(coor)
        new_coor[0] = coor[1]
        new_coor[1] = coor[0]
        new_coor[2] = coor[3]
        new_coor[3] = coor[2]
#         coor = new_coor
        print(f'coor_{i} - {class_name} === {coor}')
        coor[0] = int(new_coor[0] * image_h)
        coor[2] = int(new_coor[2] * image_h)
        coor[1] = int(new_coor[1] * image_w)
        coor[3] = int(new_coor[3] * image_w)
        fontScale = 0.5
        score = out_scores[0][i]
        
#         print(out_boxes.shape)  
    print('------iteration completed------')
    print(out_boxes.shape)  
    print('start drawing boxes')
    data = pyplot.imread(filename)
    # plot the image
    pyplot.imshow(data)
    # get the context for drawing boxes
    ax = pyplot.gca()
    # plot each box
    
    colors = generate_colors(labels)
    out_classes = out_classes[0]
    out_scores = out_scores[0]
    out_boxes = out_boxes[0]
    print(f'out boxes shape is  {out_boxes.shape}')
    
    for i in range(num_boxes[0]):
        box = out_boxes[i]
        # get coordinates
#         print(f'box shape is {box}')
        y1, x1, y2, x2 = box[0], box[1], box[2], box[3]
        print(f'++++++++ object = {labels[int(out_classes[i])]} -   y1, x1, y2, x2 = {box[0]}, {box[1]}, {box[2]}, {box[3]}')
        # calculate width and height of the box
        width, height = x2 - x1, y2 - y1
        print(f'object = {labels[int(out_classes[i])]}({out_scores[i]*100})  w= {width}  h= {height}')
        # create the shape
        rect = Rectangle((x1, y1), width, height, fill=False, color=colors[i])
        # draw the box
        ax.add_patch(rect)
        # draw text and score in top left corner
        label = "%s (%.3f)" % (labels[int(out_classes[i])], out_scores[i]*100)
        pyplot.text(x1, y1, label, color='yellow')
#     # show the plot
    pyplot.show()

# %% [markdown]
# # load models

# %%
# yolo_model = load_model('yolov3Keras29thMay2022.h5')
yolo_model = load_model('yolov4-608')
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
yolo_tiny_model = load_model('yolov4-tiny-23rdMay-608')
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# # load image

# %%
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array

# load and prepare an image
def load_image_pixels(filename, shape):
    # load the image to get its shape
    image = load_img(filename)
    width, height = image.size
    # load the image with the required size
    image = load_img(filename, interpolation = 'bilinear', target_size=shape)
    # convert to numpy array
    image = img_to_array(image)
    # scale pixel values to [0, 1]
    image = image.astype('float32')
    image /= 255.0

    # add a dimension so that we have one sample
    image = expand_dims(image, 0)
    
    return image, width, height

# %%
# Pre-process the image
input_w, input_h = 608, 608
photo_filename = '/Users/ankit/Downloads/darknet_pjreddie/data/IMG_3470.jpeg'
image, image_w, image_h = load_image_pixels(photo_filename, (input_w, input_h))
print("image initial size: ", image_w, image_h)
print("input image",image.shape)
# Out:
# image initial size:  4032 3024
# input image (1, 608, 608, 3)

# %% [markdown]
# # prediction

# %%
# Run the model
yhat = yolo_model.predict(image)
print(f'y hat shape = {yhat.shape}')
print("output:",[a.shape for a in yhat])
draw_bbs(photo_filename, yhat)
# [0.2395002 0.7745519 0.3014686 0.9534064]
# coor_1 - kite === [0.65966535 0.08828039 0.7445483  0.1675079 ]

# coor_0 - person === [0.2395002 0.7745519 0.3014686 0.9534064]
# Out:
# y hat shape = (1, 68, 84)
# output: [(68, 84)]
# num_boxes[0].shape = 9 out_boxes.shape = (1, 50, 4)
# ------iteration started------
# coor_0 - mouse === [0.90351987 0.62746733 0.97182786 0.675749  ]
# coor_1 - keyboard === [0.8925185 0.3004204 0.9976682 0.6264491]
# coor_2 - bottle === [0.61320305 0.8653398  0.88789326 0.9366549 ]
# coor_3 - tvmonitor === [0.50193584 0.11893611 0.8292     0.54650164]
# coor_4 - book === [0.15479837 0.49530146 0.18914294 0.640797  ]
# coor_5 - book === [0.14031804 0.7672651  0.2662771  0.7987641 ]
# coor_6 - book === [0.1392535  0.81051606 0.2685381  0.84126663]
# coor_7 - book === [0.13799928 0.7373922  0.26869482 0.7657266 ]
# coor_8 - book === [0.14213492 0.7925363  0.26692733 0.8158732 ]
# ------iteration completed------
# (1, 50, 4)
# start drawing boxes
# out boxes shape is  (50, 4)
# ++++++++ object = mouse -   y1, x1, y2, x2 = 2732.0, 2529.0, 2938.0, 2724.0
# object = mouse(99.68563318252563)  w= 195.0  h= 206.0
# ++++++++ object = keyboard -   y1, x1, y2, x2 = 2698.0, 1211.0, 3016.0, 2525.0
# object = keyboard(98.19515943527222)  w= 1314.0  h= 318.0
# ++++++++ object = bottle -   y1, x1, y2, x2 = 1854.0, 3489.0, 2684.0, 3776.0
# object = bottle(96.30707502365112)  w= 287.0  h= 830.0
# ++++++++ object = tvmonitor -   y1, x1, y2, x2 = 1517.0, 479.0, 2507.0, 2203.0
# object = tvmonitor(96.18450403213501)  w= 1724.0  h= 990.0
# ++++++++ object = book -   y1, x1, y2, x2 = 468.0, 1997.0, 571.0, 2583.0
# object = book(73.27595949172974)  w= 586.0  h= 103.0
# ++++++++ object = book -   y1, x1, y2, x2 = 424.0, 3093.0, 805.0, 3220.0
# object = book(64.54098224639893)  w= 127.0  h= 381.0
# ++++++++ object = book -   y1, x1, y2, x2 = 421.0, 3268.0, 812.0, 3391.0
# object = book(59.394705295562744)  w= 123.0  h= 391.0
# ++++++++ object = book -   y1, x1, y2, x2 = 417.0, 2973.0, 812.0, 3087.0
# object = book(54.244256019592285)  w= 114.0  h= 395.0
# ++++++++ object = book -   y1, x1, y2, x2 = 429.0, 3195.0, 807.0, 3289.0
# object = book(53.12419533729553)  w= 94.0  h= 378.0

# %%
# Run the model
ytinyhat = yolo_tiny_model.predict(image)
print(f"ytinyhat shape : {ytinyhat.shape}")
print("output:",[a.shape for a in yhat])
draw_bbs(photo_filename, ytinyhat)
# Out:
# ytinyhat shape : (1, 20, 84)
# output: [(68, 84)]
# num_boxes[0].shape = 4 out_boxes.shape = (1, 50, 4)
# ------iteration started------
# coor_0 - mouse === [0.90203345 0.6251611  0.96697444 0.67914563]
# coor_1 - keyboard === [0.8901895  0.29405445 0.9985633  0.64157456]
# coor_2 - tvmonitor === [0.4654112  0.11348805 0.8647269  0.5746549 ]
# coor_3 - bottle === [0.61580336 0.8665833  0.8882351  0.9393195 ]
# ------iteration completed------
# (1, 50, 4)
# start drawing boxes
# out boxes shape is  (50, 4)
# ++++++++ object = mouse -   y1, x1, y2, x2 = 2727.0, 2520.0, 2924.0, 2738.0
# object = mouse(97.94883131980896)  w= 218.0  h= 197.0
# ++++++++ object = keyboard -   y1, x1, y2, x2 = 2691.0, 1185.0, 3019.0, 2586.0
# object = keyboard(97.33119606971741)  w= 1401.0  h= 328.0
# ++++++++ object = tvmonitor -   y1, x1, y2, x2 = 1407.0, 457.0, 2614.0, 2317.0
# object = tvmonitor(57.09971785545349)  w= 1860.0  h= 1207.0
# ++++++++ object = bottle -   y1, x1, y2, x2 = 1862.0, 3494.0, 2686.0, 3787.0
# object = bottle(54.846155643463135)  w= 293.0  h= 824.0

# %% [markdown]
# # convert to coreml

# %%
import coremltools as ct

coreml_model = ct.convert(yolo_model, inputs=[ct.ImageType(scale=1 / 255.0)])
# Out:
# 2022-05-29 18:46:54.839688: I tensorflow/core/grappler/devices.cc:60] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA support)
# 2022-05-29 18:46:54.839781: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-05-29 18:46:54.878839: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:797] Optimization results for grappler item: graph_to_optimize
# 2022-05-29 18:46:54.878861: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 2022-05-29 18:46:54.878867: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 2022-05-29 18:47:05.052753: I tensorflow/core/grappler/devices.cc:60] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA support)
# 2022-05-29 18:47:05.053045: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-05-29 18:47:10.811882: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:797] Optimization results for grappler item: graph_to_optimize
# 2022-05-29 18:47:10.811915: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   constant_folding: Graph size after: 1345 nodes (-541), 1493 edges (-539), time = 2544.60303ms.
# 2022-05-29 18:47:10.811921: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   dependency_optimizer: Graph size after: 1345 nodes (0), 1493 edges (0), time = 172.54ms.
# 2022-05-29 18:47:10.811925: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   debug_stripper: debug_stripper did nothing. time = 30.392ms.
# 2022-05-29 18:47:10.811928: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   constant_folding: Graph size after: 1345 nodes (0), 1493 edges (0), time = 410.291ms.
# 2022-05-29 18:47:10.811932: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   dependency_optimizer: Graph size after: 1345 nodes (0), 1493 edges (0), time = 176.129ms.
# 2022-05-29 18:47:10.811937: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   debug_stripper: debug_stripper did nothing. time = 30.827ms.
# 2022-05-29 18:47:12.960425: I tensorflow/core/grappler/devices.cc:60] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA support)
# 2022-05-29 18:47:12.960511: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-05-29 18:47:12.997230: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:797] Optimization results for grappler item: graph_to_optimize
# 2022-05-29 18:47:12.997247: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2022-05-29 18:47:12.997252: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-05-29 18:47:21.142420: I tensorflow/core/grappler/devices.cc:60] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA support)
# 2022-05-29 18:47:21.142544: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-05-29 18:47:26.898603: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:797] Optimization results for grappler item: graph_to_optimize
# 2022-05-29 18:47:26.898624: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   constant_folding: Graph size after: 1345 nodes (-541), 1493 edges (-539), time = 2805.5271ms.
# 2022-05-29 18:47:26.898628: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   dependency_optimizer: Graph size after: 1345 nodes (0), 1493 edges (0), time = 175.518ms.
# 2022-05-29 18:47:26.898632: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   debug_stripper: debug_stripper did nothing. time = 29.709ms.
# 2022-05-29 18:47:26.898636: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   constant_folding: Graph size after: 1345 nodes (0), 1493 edges (0), time = 409.728ms.
# 2022-05-29 18:47:26.898640: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   dependency_optimizer: Graph size after: 1345 nodes (0), 1493 edges (0), time = 173.56ms.
# 2022-05-29 18:47:26.898643: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   debug_stripper: debug_stripper did nothing. time = 30.058ms.
# Running TensorFlow Graph Passes: 100%|███████| 5/5 [00:08<00:00,  1.63s/ passes]
# Converting Frontend ==> MIL Ops: 100%|███| 1359/1359 [00:04<00:00, 274.01 ops/s]
# Running MIL optimization passes: 100%|█████| 16/16 [00:03<00:00,  4.02 passes/s]
# Translating MIL ==> MLModel Ops: 100%|███| 2001/2001 [00:11<00:00, 181.35 ops/s]

# %%
print(coreml_model)
# Out:
# input {
#   name: "input_1"
#   type {
#     imageType {
#       width: 608
#       height: 608
#       colorSpace: RGB
#       imageSizeRange {
#         widthRange {
#           lowerBound: 608
#           upperBound: 608
#         }
#         heightRange {
#           lowerBound: 608
#           upperBound: 608
#         }
#       }
#     }
#   }
# }
# output {
#   name: "Identity"
#   type {
#     multiArrayType {
#       dataType: FLOAT32
#     }
#   }
# }
# metadata {
#   userDefined {
#     key: "com.github.apple.coremltools.source"
#     value: "tensorflow==2.2.0"
#   }
#   userDefined {
#     key: "com.github.apple.coremltools.version"
#     value: "4.0b3"
#   }
# }

# %%
output_path = 'yolov3Coreml_29thMay2022'
coreml_model.save(output_path)
print('Saved CoreML model to {}'.format(output_path))
# Out:
# Saved CoreML model to yolov3Coreml_29thMay2022

# %%
from PIL import Image
def load_local_and_scale_image(image_path):
    image = Image.open(image_path)
    w,h = image.size
    min_dim = min(w,h)
    x0 = 0 #int((w - min_dim)/2)
    y0 = 0 #int((h - min_dim)/2)
    box = (x0, y0, x0 + min_dim, y0 + min_dim)
#     return image.crop(box=box).resize((608,608))
    return image.resize((608,608))

# %%
image = load_local_and_scale_image(photo_filename)
image
# Out:
# <PIL.Image.Image image mode=RGB size=608x608 at 0x7FE6F97C5B50>

# %%
INPUT_NODE = 'input_1'
OUTPUT_NODE = 'Identity'
print(f'{INPUT_NODE} -- {OUTPUT_NODE}')
# Out:
# input_1 -- Identity

# %%
preds = coreml_model.predict(data={INPUT_NODE: image})[OUTPUT_NODE]

# %%
print(preds.shape)
# Out:
# (1, 72, 84)

# %%
draw_bbs_coreml(photo_filename, preds)
# Out:
# num_boxes[0].shape = 9 out_boxes.shape = (1, 50, 4)
# ------iteration staretd------
# coor_0 - mouse === [0.6275708  0.9035173  0.6758176  0.97216076]
# coor_1 - keyboard === [0.30041015 0.8923583  0.62635815 0.99770737]
# coor_2 - bottle === [0.86568433 0.6134573  0.93636566 0.88797   ]
# coor_3 - tvmonitor === [0.11878034 0.5009979  0.5471922  0.82920873]
# coor_4 - book === [0.4955222  0.15446351 0.640678   0.18928714]
# coor_5 - book === [0.7667866  0.1401463  0.7992721  0.26671746]
# coor_6 - book === [0.8100741  0.13869905 0.84154457 0.26856616]
# coor_7 - book === [0.737357   0.13800822 0.7659769  0.26900852]
# coor_8 - book === [0.7925312  0.1416155  0.81603456 0.26725435]
# ------iteration completed------
# (1, 50, 4)
# start drawing boxes
# out boxes shape is  (50, 4)
# ++++++++ object = mouse -   y1, x1, y2, x2 = 2732.0, 2530.0, 2939.0, 2724.0
# object = mouse(99.68480467796326)  w= 194.0  h= 207.0
# ++++++++ object = keyboard -   y1, x1, y2, x2 = 2698.0, 1211.0, 3017.0, 2525.0
# object = keyboard(98.30657839775085)  w= 1314.0  h= 319.0
# ++++++++ object = bottle -   y1, x1, y2, x2 = 1855.0, 3490.0, 2685.0, 3775.0
# object = bottle(96.74190878868103)  w= 285.0  h= 830.0
# ++++++++ object = tvmonitor -   y1, x1, y2, x2 = 1515.0, 478.0, 2507.0, 2206.0
# object = tvmonitor(96.29449844360352)  w= 1728.0  h= 992.0
# ++++++++ object = book -   y1, x1, y2, x2 = 467.0, 1997.0, 572.0, 2583.0
# object = book(76.43001675605774)  w= 586.0  h= 105.0
# ++++++++ object = book -   y1, x1, y2, x2 = 423.0, 3091.0, 806.0, 3222.0
# object = book(65.07071256637573)  w= 131.0  h= 383.0
# ++++++++ object = book -   y1, x1, y2, x2 = 419.0, 3266.0, 812.0, 3393.0
# object = book(60.70207953453064)  w= 127.0  h= 393.0
# ++++++++ object = book -   y1, x1, y2, x2 = 417.0, 2973.0, 813.0, 3088.0
# object = book(57.59332776069641)  w= 115.0  h= 396.0
# ++++++++ object = book -   y1, x1, y2, x2 = 428.0, 3195.0, 808.0, 3290.0
# object = book(53.809285163879395)  w= 95.0  h= 380.0

# %%
# tiny 
coreml_tiny_model = ct.convert(yolo_tiny_model, inputs=[ct.ImageType(scale=1 / 255.0)])
# Out:
# 2022-05-29 21:01:55.081395: I tensorflow/core/grappler/devices.cc:60] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA support)
# 2022-05-29 21:01:55.081503: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-05-29 21:01:55.123699: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:797] Optimization results for grappler item: graph_to_optimize
# 2022-05-29 21:01:55.123720: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 2022-05-29 21:01:55.123726: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2022-05-29 21:01:56.448430: I tensorflow/core/grappler/devices.cc:60] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA support)
# 2022-05-29 21:01:56.448565: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-05-29 21:01:56.816755: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:797] Optimization results for grappler item: graph_to_optimize
# 2022-05-29 21:01:56.816775: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   constant_folding: Graph size after: 412 nodes (-99), 452 edges (-97), time = 193.983ms.
# 2022-05-29 21:01:56.816780: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   dependency_optimizer: Graph size after: 412 nodes (0), 452 edges (0), time = 11.712ms.
# 2022-05-29 21:01:56.816784: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   debug_stripper: debug_stripper did nothing. time = 1.567ms.
# 2022-05-29 21:01:56.816788: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   constant_folding: Graph size after: 412 nodes (0), 452 edges (0), time = 36.867ms.
# 2022-05-29 21:01:56.816791: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   dependency_optimizer: Graph size after: 412 nodes (0), 452 edges (0), time = 10.667ms.
# 2022-05-29 21:01:56.816795: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   debug_stripper: debug_stripper did nothing. time = 1.445ms.
# 2022-05-29 21:01:57.318754: I tensorflow/core/grappler/devices.cc:60] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA support)
# 2022-05-29 21:01:57.318849: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-05-29 21:01:57.331448: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:797] Optimization results for grappler item: graph_to_optimize
# 2022-05-29 21:01:57.331466: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   function_optimizer: function_optimizer did nothing. time = 0.003ms.
# 2022-05-29 21:01:57.331471: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 2022-05-29 21:01:58.509507: I tensorflow/core/grappler/devices.cc:60] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA support)
# 2022-05-29 21:01:58.509624: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-05-29 21:01:58.876555: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:797] Optimization results for grappler item: graph_to_optimize
# 2022-05-29 21:01:58.876575: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   constant_folding: Graph size after: 412 nodes (-99), 452 edges (-97), time = 192.66ms.
# 2022-05-29 21:01:58.876580: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   dependency_optimizer: Graph size after: 412 nodes (0), 452 edges (0), time = 11.729ms.
# 2022-05-29 21:01:58.876584: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   debug_stripper: debug_stripper did nothing. time = 1.565ms.
# 2022-05-29 21:01:58.876587: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   constant_folding: Graph size after: 412 nodes (0), 452 edges (0), time = 36.759ms.
# 2022-05-29 21:01:58.876591: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   dependency_optimizer: Graph size after: 412 nodes (0), 452 edges (0), time = 10.807ms.
# 2022-05-29 21:01:58.876595: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   debug_stripper: debug_stripper did nothing. time = 1.46ms.
# Running TensorFlow Graph Passes: 100%|███████| 5/5 [00:01<00:00,  3.04 passes/s]
# Converting Frontend ==> MIL Ops: 100%|█████| 425/425 [00:01<00:00, 380.63 ops/s]
# Running MIL optimization passes: 100%|█████| 16/16 [00:01<00:00, 15.36 passes/s]
# Translating MIL ==> MLModel Ops: 100%|█████| 602/602 [00:01<00:00, 593.14 ops/s]

# %%
print(coreml_tiny_model)
# Out:
# input {
#   name: "input_1"
#   type {
#     imageType {
#       width: 608
#       height: 608
#       colorSpace: RGB
#       imageSizeRange {
#         widthRange {
#           lowerBound: 608
#           upperBound: 608
#         }
#         heightRange {
#           lowerBound: 608
#           upperBound: 608
#         }
#       }
#     }
#   }
# }
# output {
#   name: "Identity"
#   type {
#     multiArrayType {
#       dataType: FLOAT32
#     }
#   }
# }
# metadata {
#   userDefined {
#     key: "com.github.apple.coremltools.source"
#     value: "tensorflow==2.2.0"
#   }
#   userDefined {
#     key: "com.github.apple.coremltools.version"
#     value: "4.0b3"
#   }
# }

# %%
output_path = 'yolov3Coreml_tiny_29thMay2022'
coreml_tiny_model.save(output_path)
print('Saved CoreML model to {}'.format(output_path))
# Out:
# Saved CoreML model to yolov3Coreml_tiny_29thMay2022

# %%
preds_tiny = coreml_tiny_model.predict(data={INPUT_NODE: image})[OUTPUT_NODE]
print(preds_tiny.shape)
# Out:
# (1, 18, 84)

# %%
draw_bbs_coreml(photo_filename, preds_tiny)
# Out:
# num_boxes[0].shape = 3 out_boxes.shape = (1, 50, 4)
# ------iteration staretd------
# coor_0 - mouse === [0.6293608  0.9054586  0.6768342  0.97030973]
# coor_1 - keyboard === [0.29312444 0.8904193  0.64246136 0.9988396 ]
# coor_2 - tvmonitor === [0.10974028 0.47011477 0.5766656  0.8606397 ]
# ------iteration completed------
# (1, 50, 4)
# start drawing boxes
# out boxes shape is  (50, 4)
# ++++++++ object = mouse -   y1, x1, y2, x2 = 2738.0, 2537.0, 2934.0, 2728.0
# object = mouse(97.96955585479736)  w= 191.0  h= 196.0
# ++++++++ object = keyboard -   y1, x1, y2, x2 = 2692.0, 1181.0, 3020.0, 2590.0
# object = keyboard(97.56903052330017)  w= 1409.0  h= 328.0
# ++++++++ object = tvmonitor -   y1, x1, y2, x2 = 1421.0, 442.0, 2602.0, 2325.0
# object = tvmonitor(56.7985475063324)  w= 1883.0  h= 1181.0

# %%
# quantized model
coreml_tiny_model_quantized = ct.models.neural_network.quantization_utils.quantize_weights(
    coreml_tiny_model, 
    nbits=16, 
    quantization_mode='linear')
# Out:
# Quantizing using linear quantization
# Quantizing layer model/conv2d/Conv2Dx
# Quantizing layer batch_norm_126
# Quantizing layer model/conv2d_1/Conv2Dx
# Quantizing layer batch_norm_127
# Quantizing layer model/conv2d_2/Conv2Dx
# Quantizing layer batch_norm_128
# Quantizing layer model/conv2d_3/Conv2Dx
# Quantizing layer batch_norm_129
# Quantizing layer model/conv2d_4/Conv2Dx
# Quantizing layer batch_norm_130
# Quantizing layer model/conv2d_5/Conv2Dx
# Quantizing layer batch_norm_131
# Quantizing layer model/conv2d_6/Conv2Dx
# Quantizing layer batch_norm_132
# Quantizing layer model/conv2d_7/Conv2Dx
# Quantizing layer batch_norm_133
# Quantizing layer model/conv2d_8/Conv2Dx
# Quantizing layer batch_norm_134
# Quantizing layer model/conv2d_9/Conv2Dx
# Quantizing layer batch_norm_135
# Quantizing layer model/conv2d_10/Conv2Dx
# Quantizing layer batch_norm_136
# Quantizing layer model/conv2d_11/Conv2Dx
# Quantizing layer batch_norm_137
# Quantizing layer model/conv2d_12/Conv2Dx
# Quantizing layer batch_norm_138
# Quantizing layer model/conv2d_13/Conv2Dx
# Quantizing layer batch_norm_139
# Quantizing layer model/conv2d_14/Conv2Dx
# Quantizing layer batch_norm_140
# Quantizing layer model/conv2d_15/Conv2Dx
# Quantizing layer batch_norm_141
# Quantizing layer model/conv2d_18/Conv2Dx
# Quantizing layer model/conv2d_16/Conv2Dx
# Quantizing layer batch_norm_142
# Quantizing layer batch_norm_143
# Quantizing layer model/conv2d_17/Conv2Dx
# Quantizing layer model/conv2d_19/Conv2Dx
# Quantizing layer batch_norm_144
# Quantizing layer model/conv2d_20/Conv2Dx

# %%
output_path = 'yolov3Coreml_tiny_quantized_29thMay2022'
coreml_tiny_model_quantized.save(output_path)
print('Saved CoreML model to {}'.format(output_path))
# Out:
# Saved CoreML model to yolov3Coreml_tiny_quantized_29thMay2022

# %%
preds_tiny_quantized = coreml_tiny_model_quantized.predict(data={INPUT_NODE: image})[OUTPUT_NODE]
print(preds_tiny.shape)
# Out:
# (1, 18, 84)

# %%
draw_bbs_coreml(photo_filename, preds_tiny_quantized)
# Out:
# num_boxes[0].shape = 3 out_boxes.shape = (1, 50, 4)
# ------iteration staretd------
# coor_0 - mouse === [0.6293799  0.90545434 0.67682725 0.97032183]
# coor_1 - keyboard === [0.2929867 0.8904169 0.6426016 0.9988575]
# coor_2 - tvmonitor === [0.10980072 0.4701263  0.57660687 0.86060286]
# ------iteration completed------
# (1, 50, 4)
# start drawing boxes
# out boxes shape is  (50, 4)
# ++++++++ object = mouse -   y1, x1, y2, x2 = 2738.0, 2537.0, 2934.0, 2728.0
# object = mouse(97.97183871269226)  w= 191.0  h= 196.0
# ++++++++ object = keyboard -   y1, x1, y2, x2 = 2692.0, 1181.0, 3020.0, 2590.0
# object = keyboard(97.5633978843689)  w= 1409.0  h= 328.0
# ++++++++ object = tvmonitor -   y1, x1, y2, x2 = 1421.0, 442.0, 2602.0, 2324.0
# object = tvmonitor(56.93269371986389)  w= 1882.0  h= 1181.0

# %% [markdown]
# # crash course of numpy

# %%
def softmax(x):
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum()

def softmax_2d(x, axis=1):
    x_max = np.max(x, axis=axis)[:, np.newaxis]
    e_x = np.exp(x - x_max)
    x_sum = np.sum(e_x, axis=axis)[:, np.newaxis]    
    return e_x / x_sum

# %%
x = np.array([[100, 20, 11],[9, 24, 10],[3, 4, 13],[5, 6, 15],[7, 8, -14]])
x
# Out:
# array([[100,  20,  11],
#        [  9,  24,  10],
#        [  3,   4,  13],
#        [  5,   6,  15],
#        [  7,   8, -14]])

# %%
x.shape
# Out:
# (5, 3)

# %%
softmax_x = softmax(x)
softmax_x
# Out:
# array([[1.00000000e+00, 1.80485139e-35, 2.22736356e-39],
#        [3.01440879e-40, 9.85415469e-34, 8.19401262e-40],
#        [7.47197234e-43, 2.03109266e-42, 1.64581143e-38],
#        [5.52108228e-42, 1.50078576e-41, 1.21609930e-37],
#        [4.07955867e-41, 1.10893902e-40, 3.09335001e-50]])

# %%
np.max(x)
# Out:
# 100

# %%
diff_x = x - np.max(x)
diff_x
# Out:
# array([[   0,  -80,  -89],
#        [ -91,  -76,  -90],
#        [ -97,  -96,  -87],
#        [ -95,  -94,  -85],
#        [ -93,  -92, -114]])

# %%
diff_x.sum()
# Out:
# -1279

# %%
diff_x /2
# Out:
# array([[  0. , -40. , -44.5],
#        [-45.5, -38. , -45. ],
#        [-48.5, -48. , -43.5],
#        [-47.5, -47. , -42.5],
#        [-46.5, -46. , -57. ]])

# %%
softmax_2d_x = softmax_2d(x)
softmax_2d_x
# Out:
# array([[1.00000000e+00, 1.80485139e-35, 2.22736356e-39],
#        [3.05901973e-07, 9.99998863e-01, 8.31527773e-07],
#        [4.53922671e-05, 1.23388975e-04, 9.99831219e-01],
#        [4.53922671e-05, 1.23388975e-04, 9.99831219e-01],
#        [2.68941421e-01, 7.31058578e-01, 2.03926458e-10]])

# %%
x_max = np.max(x, axis=1)
x_max
# Out:
# array([100,  24,  13,  15,   8])

# %%
x_max_exp_dim_1 = tf.reshape(x_max, shape=(-1, 1)) 
x_max_exp_dim_1
# Out:
# <tf.Tensor: shape=(5, 1), dtype=int64, numpy=
# array([[100],
#        [ 24],
#        [ 13],
#        [ 15],
#        [  8]])>

# %%
x_max_exp_dim_2 = x_max.reshape(-1,1)
print(x_max_exp_dim_2)
print(x_max_exp_dim_2.shape)
# Out:
# [[100]
#  [ 24]
#  [ 13]
#  [ 15]
#  [  8]]
# (5, 1)

# %%
x_max_exp_dim_3 = x_max[:, np.newaxis]
print(x_max_exp_dim_1)
print(x_max_exp_dim_1.shape)
# Out:
# tf.Tensor(
# [[100]
#  [ 24]
#  [ 13]
#  [ 15]
#  [  8]], shape=(5, 1), dtype=int64)
# (5, 1)

# %%
print(x)
print('------------------')
print(x - x_max_exp_dim_1)
# Out:
# [[100  20  11]
#  [  9  24  10]
#  [  3   4  13]
#  [  5   6  15]
#  [  7   8 -14]]
# ------------------
# tf.Tensor(
# [[  0 -80 -89]
#  [-15   0 -14]
#  [-10  -9   0]
#  [-10  -9   0]
#  [ -1   0 -22]], shape=(5, 3), dtype=int64)

# %%
x_sum = np.sum(e_x, axis=1)
x_sum
# Out:
# array([1.00012342, 1.00000114, 1.00016881, 1.00016881, 1.00339063])

# %%
np.sum([5.60279644e-09, 1.00000000e+00, 1.23409804e-04])
# Out:
# 1.0001234154067964

# %%
test_arr = np.array([1,2,3,4,5,6]).reshape(1,-1)
print(test_arr)
print(test_arr.shape)
# test_arr = tf.reshape(test_arr, shape=(1, 6))
# print(test_arr.shape)
# print(test_arr)
print('-----------------')
test_arr = tf.reshape(test_arr, shape=(3, 2))
print(test_arr.shape)
print(test_arr)
# Out:
# [[1 2 3 4 5 6]]
# (1, 6)
# -----------------
# (3, 2)
# tf.Tensor(
# [[1 2]
#  [3 4]
#  [5 6]], shape=(3, 2), dtype=int64)

# %%
test_arr[..., :1]
# Out:
# <tf.Tensor: shape=(3, 1), dtype=int64, numpy=
# array([[1],
#        [3],
#        [5]])>

# %%
test_arr2 = [[3,7, 1], [5, -22, 100], [7, -2, 100]]
test_arr2 = sorted(test_arr2, key= lambda p : p[0], reverse=True)
print(test_arr2)
# Out:
# [[7, -2, 100], [5, -22, 100], [3, 7, 1]]

# %%
test_arr3 = np.array([[3,7, 1], [5, -22, 100], [7, -2, 100]])
print(test_arr3)
# Out:
# [[  3   7   1]
#  [  5 -22 100]
#  [  7  -2 100]]

# %%
np.transpose(test_arr3, (1, 0))
# Out:
# array([[  3,   5,   7],
#        [  7, -22,  -2],
#        [  1, 100, 100]])
